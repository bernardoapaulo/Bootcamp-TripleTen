# %% [markdown]
# ## Passo 4. Análise exploratória de dados (Python)

# %%
#imports
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
#caminho do arquivo

df = pd.read_csv('/datasets/project_sql_result_01.csv')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os arquivos de dados foram carregados corretamente
# - As bibliotecas foram carregadas corretamente e em uma célula separada
# </div>

# %%
#Arquivo 1
# estudar os dados
print(df.info())

print()

#verificar valores ausentes
print(df.isnull().sum())

print()

print(df.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64 entries, 0 to 63
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  64 non-null     object
#  1   trips_amount  64 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 1.1+ KB
# None
#
# company_name    0
# trips_amount    0
# dtype: int64
#
#                       company_name  trips_amount
# 0                        Flash Cab         19558
# 1        Taxi Affiliation Services         11422
# 2                Medallion Leasing         10367
# 3                       Yellow Cab          9888
# 4  Taxi Affiliation Service Yellow          9299

# %% [markdown]
# - Não foi identificado nenhum tipo de valor ausente ou de dados incorretos.

# %%
#caminho arquivo 2
df_t = pd.read_csv('/datasets/project_sql_result_04.csv')

# %%
# estudas os dados do arquivo 2
print(df_t.info())

print()

print(df_t.isnull().sum())

print()

print(df_t.describe())

print()

print(df_t.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 2 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   dropoff_location_name  94 non-null     object
#  1   average_trips          94 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 1.6+ KB
# None
#
# dropoff_location_name    0
# average_trips            0
# dtype: int64
#
#        average_trips
# count      94.000000
# mean      599.953728
# std      1714.591098
# min         1.800000
# 25%        14.266667
# 50%        52.016667
# 75%       298.858333
# max     10727.466667
#
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000

# %% [markdown]
# - Não foi identificado nenhum tipo de valor ausente ou de dados incorretos.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O método `head()` foi  utilizado para exibir uma amostra inicial dos seus dados
# - O método `info()` foi utilizado para estudo inicial do conjunto de dados
# - Os valores ausentes foram analisados
# - **Sugestão:** você poderia executar os comandos acima para isolar a execução do código. Além disso, você poderia usar o método `.describe()` também para analisar as estatísticas descritivas dos dados
#
# </div>

# %%
#10 principais bairros

top_10_bairros = df_t.sort_values(by='average_trips', ascending=False).head(10)
print(top_10_bairros)
# Out:
#   dropoff_location_name  average_trips
# 0                  Loop   10727.466667
# 1           River North    9523.666667
# 2         Streeterville    6664.666667
# 3             West Loop    5163.666667
# 4                O'Hare    2546.900000
# 5             Lake View    2420.966667
# 6            Grant Park    2068.533333
# 7         Museum Campus    1510.000000
# 8            Gold Coast    1364.233333
# 9    Sheffield & DePaul    1259.766667

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# Os 10 principais bairros de destino foram calculados
# </div>

# %%
#Gráfico de barras para empresas de táxi e número de corridas

plt.figure(figsize=(14, 10))
sns.barplot(x='trips_amount', y='company_name', data=df, palette='viridis')
plt.title('Número de Corridas por Empresa de Táxi', fontsize=18)
plt.xlabel('Número de Corridas', fontsize=14)
plt.ylabel('Empresa de Táxi', fontsize=14)
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O número de corridas por empresa foi analisado
# - Um gráfico de barras foi apresentado. Sugestão: aqui você poderia filtrar o conjunto acima para remover empresas que tiveram poucas ou quase nenhuma corrida. Perceba que a distribuição é concentrada em poucas empresas
# - Obs.: Bom trabalho exibindo as 10 empresas com maior número de corridas
# </div>

# %%
#Gráfico para os Top 10 Bairros com Maior Número de Corridas (Destino)
plt.figure(figsize=(12, 8))
sns.barplot(x='average_trips', y='dropoff_location_name', data=top_10_bairros, palette='viridis')
plt.title('Top 10 Bairros por Número de Corridas em que o Bairro é Destino')
plt.xlabel('Número Médio de Corridas')
plt.ylabel('Bairro de Destino')
plt.show()

# %% [markdown]
# ### Conclusões Gerais:

# %% [markdown]
# - Mercado de Taxis:
#
# O mercado de táxi é dominado por algumas grandes empresas, com Flash Cab liderando claramente em termos de número de corridas. Isso pode indicar que essas empresas têm vantagens competitivas, como maior frota, melhores serviços ou maior fidelidade dos clientes.
#
# - Principais destinos:
#
# Os principais destinos de corridas de táxi são áreas centrais, como Loop e River North, além de locais estratégicos como o aeroporto O'Hare. Esses dados podem ser úteis para entender os padrões de mobilidade urbana e para empresas de táxi que desejam otimizar suas operações.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - Os 10 principais bairros em número de corridas foram analisados
# - Um gráfico de barras foi construído
# - Bom trabalho com as conclusões gerais dessa seção
# </div>

# %% [markdown]
# ## Passo 4. Testando hipóteses (Python)

# %%
#caminho do arquivo

hp = pd.read_csv('/datasets/project_sql_result_07.csv')

# %%
#Arquivo 3
# estudar os dados
print(hp.info())

print()

#verificar valores ausentes
print(hp.isnull().sum())

print()

print(hp.head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   object
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 25.2+ KB
# None
#
# start_ts              0
# weather_conditions    0
# duration_seconds      0
# dtype: int64
#
#               start_ts weather_conditions  duration_seconds
# 0  2017-11-25 16:00:00               Good            2410.0
# 1  2017-11-25 14:00:00               Good            1920.0
# 2  2017-11-25 12:00:00               Good            1543.0
# 3  2017-11-04 10:00:00               Good            2512.0
# 4  2017-11-11 07:00:00               Good            1440.0

# %%
#converter dados para datetime
hp['start_ts'] = pd.to_datetime(hp['start_ts'])
print(hp.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   start_ts            1068 non-null   datetime64[ns]
#  1   weather_conditions  1068 non-null   object
#  2   duration_seconds    1068 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 25.2+ KB
# None

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b> Comentário do revisor: </b> <a class="tocSkip"></a>
#
# - O atributo com o timestamp foi convertido corretamente para data
# - O método `info()` foi utilizado para verificar a modificação no tipo de dados
# </div>

# %%
#filtrar os dados apenas para sabados chuvosos
hp['day_of_week'] = hp['start_ts'].dt.day_name()
hp_saturdays = hp[hp['day_of_week'] == 'Saturday']

#dias chuvosos e dias não chuvosos
hp_saturdays_rainy = hp_saturdays[hp_saturdays['weather_conditions'] == 'Bad']
hp_saturdays_no_rainy = hp_saturdays[hp_saturdays['weather_conditions'] != 'Bad']

print(hp_saturdays_rainy.head())
print(hp_saturdays_no_rainy.head())
print(f'Número de registros de sábados com más condições climáticas: {len(hp_saturdays_rainy)}')
print(f'Número de registros de sábados com boas condições climáticas: {len(hp_saturdays_no_rainy)}')
# Out:
#               start_ts weather_conditions  duration_seconds day_of_week
# 6  2017-11-04 16:00:00                Bad            2969.0    Saturday
# 30 2017-11-18 12:00:00                Bad            1980.0    Saturday
# 34 2017-11-04 17:00:00                Bad            2460.0    Saturday
# 51 2017-11-04 16:00:00                Bad            2760.0    Saturday
# 52 2017-11-18 12:00:00                Bad            2460.0    Saturday
#              start_ts weather_conditions  duration_seconds day_of_week
# 0 2017-11-25 16:00:00               Good            2410.0    Saturday
# 1 2017-11-25 14:00:00               Good            1920.0    Saturday
# 2 2017-11-25 12:00:00               Good            1543.0    Saturday
# 3 2017-11-04 10:00:00               Good            2512.0    Saturday
# 4 2017-11-11 07:00:00               Good            1440.0    Saturday
# Número de registros de sábados com más condições climáticas: 180
# ...

# %%
hp_saturdays_rainy
# Out:
#                 start_ts weather_conditions  duration_seconds day_of_week
# 6    2017-11-04 16:00:00                Bad            2969.0    Saturday
# 30   2017-11-18 12:00:00                Bad            1980.0    Saturday
# 34   2017-11-04 17:00:00                Bad            2460.0    Saturday
# 51   2017-11-04 16:00:00                Bad            2760.0    Saturday
# 52   2017-11-18 12:00:00                Bad            2460.0    Saturday
# ...                  ...                ...               ...         ...
# 1031 2017-11-18 12:00:00                Bad            2560.0    Saturday
# 1032 2017-11-18 10:00:00                Bad            1908.0    Saturday
# 1053 2017-11-18 12:00:00                Bad            2400.0    Saturday
# 1061 2017-11-18 16:00:00                Bad            2186.0    Saturday
# 1067 2017-11-04 16:00:00                Bad            2834.0    Saturday
#
# [180 rows x 4 columns]

# %%
if len(hp_saturdays_rainy) > 0 and len(hp_saturdays_no_rainy) > 0:
    hp_saturdays_rainy_var = hp_saturdays_rainy['duration_seconds'].var()
    hp_saturdays_no_rainy_var = hp_saturdays_no_rainy['duration_seconds'].var()

    print(f'Variância nos sábados com boas condições climáticas: {hp_saturdays_no_rainy_var}')
    print(f'Variância nos sábados com más condições climáticas: {hp_saturdays_rainy_var}')
# Out:
# Variância nos sábados com boas condições climáticas: 576382.009689509
# Variância nos sábados com más condições climáticas: 520294.086002483

# %% [markdown]
# #### "A duração média dos passeios do Loop para o Aeroporto Internacional O'Hare muda nos sábados chuvosos."

# %%
#Teste de hipóteses
if len(hp_saturdays_rainy) > 0 and len(hp_saturdays_no_rainy) > 0:
    # Calcular a variância das duas amostras
    hp_saturdays_rainy_var = hp_saturdays_rainy['duration_seconds'].var()
    hp_saturdays_no_rainy_var = hp_saturdays_no_rainy['duration_seconds'].var()

    print(f'Variância nos sábados com boas condições climáticas: {hp_saturdays_no_rainy_var}')
    print(f'Variância nos sábados com más condições climáticas: {hp_saturdays_rainy_var}')

    # Definir o argumento equal_var com base nas variâncias
    equal_var = hp_saturdays_rainy_var == hp_saturdays_no_rainy_var

    # Realizar o teste t
    t_stat, p_value = ttest_ind(hp_saturdays_rainy['duration_seconds'], hp_saturdays_no_rainy['duration_seconds'], equal_var=equal_var)

    # Exibir os resultados do teste t
    print(f't_stat: {t_stat}, p_value: {p_value}')

    # Decidir com base no valor-p
    alpha = 0.05
    if p_value < alpha:
        print("Rejeitamos a hipótese nula: A duração média dos passeios muda nos sábados chuvosos.")
    else:
        print("Falhamos em rejeitar a hipótese nula: Não há evidência suficiente para afirmar que a duração média dos passeios muda nos sábados chuvosos.")
else:
    print("Não há registros suficientes para sábados chuvosos ou não chuvosos para realizar a análise.")
# Out:
# Não há registros suficientes para sábados chuvosos ou não chuvosos para realizar a análise.

# %% [markdown]
#  - Foi usado o nível de significância (alfa) em 0.05.
#  - Usamos o teste t para verificar se a diferença nas médias é estatisticamente significativa.
#  - Com base no p-valor, não há registros suficientes.

# %% [markdown]
# ### Conclusão

# %% [markdown]
# A análise não encontrou regitros suficientes para concluir que os passeios do Loop para o Aeroporto Internacional O'Hare têm uma duração média diferente nos sábados chuvosos em comparação com os sábados não chuvosos. Logo, qualquer planejamento ou decisão baseada na suposição de que a chuva afeta significativamente a duração dessas corridas deve ser reconsiderado, a menos que novas evidências sejam obtidas.
